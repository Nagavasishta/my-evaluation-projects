# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('adult.csv')
df
# Out:
#        age         work_class  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   work_class      32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native_country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# THERE IS NO MISSING VA;UES

# %%
df.work_class.unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
df.occupation.unique()
# Out:
# array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#        ' Prof-specialty', ' Other-service', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', ' ?', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
df.native_country.unique()
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', ' ?', ' Mexico',
#        ' South', ' Puerto-Rico', ' Honduras', ' England', ' Canada',
#        ' Germany', ' Iran', ' Philippines', ' Italy', ' Poland',
#        ' Columbia', ' Cambodia', ' Thailand', ' Ecuador', ' Laos',
#        ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic',
#        ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan',
#        ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland',
#        ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam', ' Hong',
#        ' Ireland', ' Hungary', ' Holand-Netherlands'], dtype=object)

# %% [markdown]
# THESE ARE THE MISSING STRING LET WE DO VISULAISATION AFTER THAT IT IS TRANSFORMED INTO INTEGER FILES BECAUSE FOR CLEAR VISULAIZATION

# %%
#LET WE ASSUME '?' AS OTHERS IN WORK CLASS AND OCCUPATION,NATIVE COUNTRY

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital_gain  capital_loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# AS YOU SEE HERE THE 75% AND MAX HAS LARGER DIFFERENCE IN CAPITAL GAIN AND LOSS SAME HAS MEAN AND MIN IN SAME COLUMNS

# %%
df.columns
# Out:
# Index(['age', 'work_class', 'fnlwgt', 'education', 'education-num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours-per-week', 'native_country',
#        'income'],
#       dtype='object')

# %%
plt.figure(figsize=(40,15))
sns.barplot(y='age',x='income',hue='native_country',data=df,palette='Paired')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(y='age',x='work_class',hue='income',data=df,palette='Paired')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(y='age',x='sex',hue='income',data=df)
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.barplot(y='age',x='education',hue='income',data=df,palette='ocean')
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.barplot(y='age',x='education-num',hue='income',data=df,palette='winter')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(y='age',x='marital_status',hue='income',data=df,palette='hot')
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.barplot(x='age',y='occupation',hue='income',data=df,palette='rocket')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(y='age',x='relationship',hue='income',data=df,palette='copper')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(y='age',x='race',hue='income',data=df,palette='BrBG')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='income',y='capital_gain',hue='sex',data=df,palette='Blues')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='income',y='capital_loss',hue='sex',data=df,palette='Reds')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='income',y='hours-per-week',hue='sex',data=df,palette='cubehelix')
plt.show()

# %%
plt.figure(figsize=(30,10))
sns.barplot(x='age',y='hours-per-week',data=df,palette='spring')
plt.show()

# %%
#use label encoding
from sklearn import preprocessing
le=preprocessing.LabelEncoder()
le_count=0
for col in df.columns[1:]:
    if df[col].dtype=='object':
        if len(list(df[col].unique())) <=10:
            le.fit(df[col])
            df[col]=le.transform(df[col])
            le_count +=1
print('{}columns were label encoded.'.format(le_count))
# Out:
# 0columns were label encoded.

# %%
df.dtypes
# Out:
# age                int64
# work_class         int32
# fnlwgt             int64
# education         object
# education-num      int64
# marital_status     int32
# occupation        object
# relationship       int32
# race               int32
# sex                int32
# capital_gain       int64
# capital_loss       int64
# hours-per-week     int64
# native_country    object
# income             int32
# dtype: object

# %%
label=le.fit_transform(df['education'])
le.classes_
# Out:
# array([' 10th', ' 11th', ' 12th', ' 1st-4th', ' 5th-6th', ' 7th-8th',
#        ' 9th', ' Assoc-acdm', ' Assoc-voc', ' Bachelors', ' Doctorate',
#        ' HS-grad', ' Masters', ' Preschool', ' Prof-school',
#        ' Some-college'], dtype=object)

# %%
df.drop(columns=['education'])
# Out:
#        age  work_class  fnlwgt  education-num  marital_status  \
# 0       39           7   77516             13               4
# 1       50           6   83311             13               2
# 2       38           4  215646              9               0
# 3       53           4  234721              7               2
# 4       28           4  338409             13               2
# ...    ...         ...     ...            ...             ...
# 32556   27           4  257302             12               2
# 32557   40           4  154374              9               2
# 32558   58           4  151910              9               6
# 32559   22           4  201490              9               4
# 32560   52           5  287927              9               2
#
#                occupation  relationship  race  sex  capital_gain  \
# 0            Adm-clerical             1     4    1          2174
# 1         Exec-managerial             0     4    1             0
# ...

# %%
df['education']=label
df.dtypes
# Out:
# age                int64
# work_class         int32
# fnlwgt             int64
# education          int32
# education-num      int64
# marital_status     int32
# occupation        object
# relationship       int32
# race               int32
# sex                int32
# capital_gain       int64
# capital_loss       int64
# hours-per-week     int64
# native_country    object
# income             int32
# dtype: object

# %%
label=le.fit_transform(df['occupation'])
le.classes_
# Out:
# array([' ?', ' Adm-clerical', ' Armed-Forces', ' Craft-repair',
#        ' Exec-managerial', ' Farming-fishing', ' Handlers-cleaners',
#        ' Machine-op-inspct', ' Other-service', ' Priv-house-serv',
#        ' Prof-specialty', ' Protective-serv', ' Sales', ' Tech-support',
#        ' Transport-moving'], dtype=object)

# %%
df.drop(columns=['occupation'])
# Out:
#        age  work_class  fnlwgt  education  education-num  marital_status  \
# 0       39           7   77516          9             13               4
# 1       50           6   83311          9             13               2
# 2       38           4  215646         11              9               0
# 3       53           4  234721          1              7               2
# 4       28           4  338409          9             13               2
# ...    ...         ...     ...        ...            ...             ...
# 32556   27           4  257302          7             12               2
# 32557   40           4  154374         11              9               2
# 32558   58           4  151910         11              9               6
# 32559   22           4  201490         11              9               4
# 32560   52           5  287927         11              9               2
#
#        relationship  race  sex  capital_gain  capital_loss  hours-per-week  \
# ...

# %%
df['occupation']=label
df.dtypes
# Out:
# age                int64
# work_class         int32
# fnlwgt             int64
# education          int32
# education-num      int64
# marital_status     int32
# occupation         int32
# relationship       int32
# race               int32
# sex                int32
# capital_gain       int64
# capital_loss       int64
# hours-per-week     int64
# native_country    object
# income             int32
# dtype: object

# %%
label=le.fit_transform(df['native_country'])
le.classes_
# Out:
# array([' ?', ' Cambodia', ' Canada', ' China', ' Columbia', ' Cuba',
#        ' Dominican-Republic', ' Ecuador', ' El-Salvador', ' England',
#        ' France', ' Germany', ' Greece', ' Guatemala', ' Haiti',
#        ' Holand-Netherlands', ' Honduras', ' Hong', ' Hungary', ' India',
#        ' Iran', ' Ireland', ' Italy', ' Jamaica', ' Japan', ' Laos',
#        ' Mexico', ' Nicaragua', ' Outlying-US(Guam-USVI-etc)', ' Peru',
#        ' Philippines', ' Poland', ' Portugal', ' Puerto-Rico',
#        ' Scotland', ' South', ' Taiwan', ' Thailand', ' Trinadad&Tobago',
#        ' United-States', ' Vietnam', ' Yugoslavia'], dtype=object)

# %%
df.drop(columns=['native_country'])
# Out:
#        age  work_class  fnlwgt  education  education-num  marital_status  \
# 0       39           7   77516          9             13               4
# 1       50           6   83311          9             13               2
# 2       38           4  215646         11              9               0
# 3       53           4  234721          1              7               2
# 4       28           4  338409          9             13               2
# ...    ...         ...     ...        ...            ...             ...
# 32556   27           4  257302          7             12               2
# 32557   40           4  154374         11              9               2
# 32558   58           4  151910         11              9               6
# 32559   22           4  201490         11              9               4
# 32560   52           5  287927         11              9               2
#
#        occupation  relationship  race  sex  capital_gain  capital_loss  \
# ...

# %%
df['native_country']=label
df
# Out:
#        age  work_class  fnlwgt  education  education-num  marital_status  \
# 0       39           7   77516          9             13               4
# 1       50           6   83311          9             13               2
# 2       38           4  215646         11              9               0
# 3       53           4  234721          1              7               2
# 4       28           4  338409          9             13               2
# ...    ...         ...     ...        ...            ...             ...
# 32556   27           4  257302          7             12               2
# 32557   40           4  154374         11              9               2
# 32558   58           4  151910         11              9               6
# 32559   22           4  201490         11              9               4
# 32560   52           5  287927         11              9               2
#
#        occupation  relationship  race  sex  capital_gain  capital_loss  \
# ...

# %%
df.hist(figsize=(15,10))
plt.show()

# %%
df['age'].plot.box()

# %%
df['capital_gain'].plot.box()

# %%
df['capital_loss'].plot.box()

# %%
df['education-num'].plot.box()

# %%
df['fnlwgt'].plot.box()

# %%
df['hours-per-week'].plot.box()

# %%
collist=df.columns.values
ncol=15
nrows=20
plt.figure(figsize=(ncol,8*ncol))
for i in range(1, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='orange',orient='v')
    plt.tight_layout()

# %%
sns.distplot(df['age'])

# %%
sns.distplot(df['fnlwgt'])

# %%
sns.distplot(df['education-num'])

# %%
sns.distplot(df['hours-per-week'])

# %%
df.skew()
# Out:
# age                0.558743
# work_class        -0.752024
# fnlwgt             1.446980
# education         -0.934042
# education-num     -0.311676
# marital_status    -0.013508
# occupation         0.114583
# relationship       0.786818
# race              -2.435386
# sex               -0.719293
# capital_gain      11.953848
# capital_loss       4.594629
# hours-per-week     0.227643
# native_country    -3.658303
# income             1.212430
# dtype: float64

# %%
sns.distplot(df['education'])

# %%
sns.distplot(df['marital_status'])

# %%
sns.distplot(df['occupation'])

# %%
sns.pairplot(df,size=3)

# %%
#check the correlation
df_cor=df.corr()
plt.figure(figsize=(15,7))
sns.heatmap(df_cor,annot=True,cmap='Pastel2_r')
plt.show()

# %% [markdown]
# HERE BROWN AND GREY,YELLOW COLOR SHOWS NEGITIVE CORRELATION WHERE AS REST OF THE COLORS INDICATES POSITIVE CORRELATION

# %%
#REMOVING OUTLIERS
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[0.03067056, 2.15057856, 1.06361075, ..., 0.03542945, 0.29156857,
#         0.56319851],
#        [0.83710898, 1.46373585, 1.008707  , ..., 2.22215312, 0.29156857,
#         0.56319851],
#        [0.04264203, 0.09005041, 0.2450785 , ..., 0.03542945, 0.29156857,
#         0.56319851],
#        ...,
#        [1.42360965, 0.09005041, 0.35877741, ..., 0.03542945, 0.29156857,
#         0.56319851],
#        [1.21564337, 0.09005041, 0.11095988, ..., 1.65522476, 0.29156857,
#         0.56319851],
#        [0.98373415, 0.77689313, 0.92989258, ..., 0.03542945, 0.29156857,
#         1.77557289]])

# %%
Threshold=3
print(np.where(z>3))
# Out:
# (array([    4,    10,    11, ..., 32533, 32551, 32553], dtype=int64), array([13, 12,  8, ...,  8,  8,  8], dtype=int64))

# %%
z[4][13]
# Out:
# 4.054222573713498

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#        age  work_class  fnlwgt  education  education-num  marital_status  \
# 0       39           7   77516          9             13               4
# 1       50           6   83311          9             13               2
# 2       38           4  215646         11              9               0
# 3       53           4  234721          1              7               2
# 5       37           4  284582         12             14               2
# ...    ...         ...     ...        ...            ...             ...
# 32556   27           4  257302          7             12               2
# 32557   40           4  154374         11              9               2
# 32558   58           4  151910         11              9               6
# 32559   22           4  201490         11              9               4
# 32560   52           5  287927         11              9               2
#
#        occupation  relationship  race  sex  capital_gain  capital_loss  \
# ...

# %%
print(df_new.shape,df.shape)
# Out:
# (27418, 15) (32561, 15)

# %% [markdown]
# TOTAL 5143 OUTLIERS ARE REMOVED

# %%
df=df_new

# %%
df.shape
# Out:
# (27418, 15)

# %%
#splitting
x=df.iloc[:,:-1]
x.head()
# Out:
#    age  work_class  fnlwgt  education  education-num  marital_status  \
# 0   39           7   77516          9             13               4
# 1   50           6   83311          9             13               2
# 2   38           4  215646         11              9               0
# 3   53           4  234721          1              7               2
# 5   37           4  284582         12             14               2
#
#    occupation  relationship  race  sex  capital_gain  capital_loss  \
# 0           1             1     4    1          2174             0
# 1           4             0     4    1             0             0
# 2           6             1     4    1             0             0
# 3           6             0     2    1             0             0
# 5           4             5     4    0             0             0
#
#    hours-per-week  native_country
# 0              40              39
# 1              13              39
# 2              40              39
# ...

# %%
y=df.iloc[:,14:]
y.head()
# Out:
#    income
# 0       0
# 1       0
# 2       0
# 3       0
# 5       0

# %% [markdown]
# 0-<50k,1->50k

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 0.06280168,  2.16494042, -1.14743337, ..., -0.03745229,
#          0.00820014,  0.19389053],
#        [ 0.88275243,  1.47421317, -1.08627889, ..., -0.03745229,
#         -2.41223399,  0.19389053],
#        [-0.01173929,  0.09275869,  0.31024887, ..., -0.03745229,
#          0.00820014,  0.19389053],
#        ...,
#        [ 1.47908024,  0.09275869, -0.36235546, ..., -0.03745229,
#          0.00820014,  0.19389053],
#        [-1.20439492,  0.09275869,  0.16086097, ..., -0.03745229,
#         -1.78471403,  0.19389053],
#        [ 1.03183438,  0.78348593,  1.07302835, ..., -0.03745229,
#          0.00820014,  0.19389053]])

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_curve,auc
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB

# %%
from sklearn.model_selection import train_test_split,cross_val_score
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=9,test_size=0.3,stratify=y)

# %%
print(x_train.shape,x_test.shape)
print(y_train.shape,y_test.shape)
# Out:
# (19192, 14) (8226, 14)
# (19192, 1) (8226, 1)

# %%
knn=KNeighborsClassifier()
dt=DecisionTreeClassifier(random_state=6)
sv=SVC()
lr=LogisticRegression()
gn=GaussianNB()

# %%
models = []
models.append(('KNneighborsClassifier',knn))
models.append(('DecisionTreeClassifier',dt))
models.append(('SVC',sv))
models.append(('LogisticRegression',lr))
models.append(('GaussianNB',gn))

# %%
Model = []
score = []
cvs = []
rocscore=[]
for name,model in models:
    print('***************************',name,'***************************')
    print('\n')
    Model.append(name)
    model.fit(x_train,y_train)
    print(model)
    pre=model.predict(x_test)
    print('\n')
    AS=accuracy_score(y_test,pre)
    print('AccuracyScore=',AS)
    score.append(AS*100)
    print('\n')
    sc=cross_val_score(model,x,y,cv=10,scoring='accuracy').mean()
    print('cross_val_score=',sc)
    cvs.append(sc*100)
    print('\n')
    false_positive_rate,true_positive_rate,thresholds = roc_curve(y_test,pre)
    roc_auc=auc(false_positive_rate,true_positive_rate)
    print('roc_auc_score=',roc_auc)
    rocscore.append(roc_auc*100)
    print('\n')
    print('classification_report\n',classification_report(y_test,pre))
    print('\n')
    cm=confusion_matrix(y_test,pre)
    print(cm)
    print('\n')
    plt.figure(figsize=(10,40))
    plt.subplot(911)
    plt.title(name)
    print(sns.heatmap(cm,annot=True,cmap='rocket'))
    plt.subplot(912)
    plt.title(name)
    plt.plot(false_positive_rate,true_positive_rate,label='AUC = %0.2f'% roc_auc)
    plt.plot([0,1],[0,1],'r--')
    plt.legend(loc='lower right')
    plt.ylabel('True positive rate')
    plt.xlabel('false positive rate')
    print('\n\n')
# Out:
# *************************** KNneighborsClassifier ***************************
#
#
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')
#
#
# AccuracyScore= 0.8358862144420132
#
#
# cross_val_score= 0.8374425179308398
#
#
# roc_auc_score= 0.7422788955287241
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.88      0.91      0.90      6384
#            1       0.65      0.57      0.61      1842
#
#     accuracy                           0.84      8226
#    macro avg       0.77      0.74      0.75      8226
# weighted avg       0.83      0.84      0.83      8226
#
#
#
# [[5821  563]
#  [ 787 1055]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
#
#
#
# *************************** DecisionTreeClassifier ***************************
#
#
# ...

# %%
result=pd.DataFrame({'Model':Model,'Accuracy_score':score,'Cross_val_score':cvs,'roc_auc_curve':rocscore})
result
# Out:
#                     Model  Accuracy_score  Cross_val_score  roc_auc_curve
# 0   KNneighborsClassifier       83.588621        83.744252      74.227890
# 1  DecisionTreeClassifier       81.449064        80.604031      73.428813
# 2                     SVC       84.621930        85.101023      71.726395
# 3      LogisticRegression       82.968636        82.898098      68.227878
# 4              GaussianNB       79.394602        78.831497      77.165022

# %% [markdown]
# I CHOOSE SVC IT HAS
# ACCURACY SCORE=84.621930
# CROSS_VAL_SCORE=85.101023
# ROC_AUC_CURVE=71.726395
# BUT ROC_AUC_CURVE HAS HIGHEST IN GAUSSIANNB

# %%
#prediction result
t=np.array([25,4,215646,11,8,0,5,1,3,2,0,0,40,3])

# %%
t.shape
# Out:
# (14,)

# %%
t=t.reshape(1,-1)

# %%
sv.predict(t)
# Out:
# array([0])

# %% [markdown]
# 0 means less than 50k salary

# %%
#save model
from joblib import dump,load
dump(df,'census_income.joblib')
# Out:
# ['census_income.joblib']
